# %% [markdown]
# # This will be a test doing a small bot based on the rasa nlu stack
# Based on: https://github.com/rasahq/rasa-workshop-pydata-berlin
# and the youtube videos from rasa on pydata berlin and new york

# %%
# %matplotlib inline

import logging, io, json, warnings
logging.basicConfig(level="INFO")
warnings.filterwarnings('ignore')

def pprint(o):
    # small helper to make dict dumps a bit prettier
    print(json.dumps(o, indent=2))

# %%
import sys
python = sys.executable

# In your environment run:
# !{python} -m pip install -U rasa_core rasa_nlu[spacy];

# as well as install a language model:
# !{python} -m spacy download en_core_web_md
# !{python} -m spacy link en_core_web_md en --force;
# Out:
# Collecting rasa_core
#   Using cached https://files.pythonhosted.org/packages/cd/7b/58a6a997023a8b1f6a0e292d08fd88b4d39ec325e103c6cebd1eb38f6545/rasa_core-0.14.5-py3-none-any.whl
# Collecting rasa_nlu[spacy]
#   Using cached https://files.pythonhosted.org/packages/19/c4/c6146c445a17b6ce414d773f93c941c44ca16720609000ae3d01409f9dfb/rasa_nlu-0.15.1-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: terminaltables~=3.1 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (3.1.0)
# Requirement already satisfied, skipping upgrade: gevent~=1.3 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (1.3.7)
# Collecting flask-jwt-simple~=0.0.3 (from rasa_core)
# Requirement already satisfied, skipping upgrade: questionary>=1.0.1 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (1.3.0)
# Collecting python-telegram-bot~=11.0 (from rasa_core)
#   Using cached https://files.pythonhosted.org/packages/84/6c/47932a4041ee76650ad1f45a80e1422077e1e99c08a4d7a61cfbe5393d41/python_telegram_bot-11.1.0-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: fbmessenger~=5.0 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (5.6.0)
# Requirement already satisfied, skipping upgrade: typing~=3.0 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (3.7.4.1)
# Requirement already satisfied, skipping upgrade: flask~=1.0 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (1.0.2)
# Requirement already satisfied, skipping upgrade: jsonschema~=2.6 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (2.6.0)
# Requirement already satisfied, skipping upgrade: numpy~=1.16 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (1.17.2)
# Requirement already satisfied, skipping upgrade: ruamel.yaml~=0.15.0 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (0.15.100)
# Requirement already satisfied, skipping upgrade: pymongo~=3.7 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (3.9.0)
# Requirement already satisfied, skipping upgrade: pytz~=2018.9 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (2018.9)
# Requirement already satisfied, skipping upgrade: jsonpickle~=1.0 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (1.2)
# Requirement already satisfied, skipping upgrade: apscheduler~=3.0 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (3.6.1)
# Requirement already satisfied, skipping upgrade: slackclient~=1.0 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (1.3.2)
# Requirement already satisfied, skipping upgrade: redis~=2.0 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (2.10.6)
# Collecting scikit-learn~=0.20.0 (from rasa_core)
#   Downloading https://files.pythonhosted.org/packages/87/6f/5863f1b27523c5d9f0ae2f3d07828ad383ceab39c79726d2ea4da7f679e7/scikit_learn-0.20.4-cp37-cp37m-manylinux1_x86_64.whl (5.4MB)
#     100% |████████████████████████████████| 5.4MB 3.4MB/s ta 0:00:01
# Requirement already satisfied, skipping upgrade: pykwalify~=1.7.0 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (1.7.0)
# Requirement already satisfied, skipping upgrade: coloredlogs~=10.0 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (10.0)
# Requirement already satisfied, skipping upgrade: mattermostwrapper~=2.0 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (2.1)
# Requirement already satisfied, skipping upgrade: rocketchat-API~=0.6.0 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (0.6.34)
# Requirement already satisfied, skipping upgrade: scipy~=1.2 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (1.3.1)
# Requirement already satisfied, skipping upgrade: rasa-core-sdk~=0.14 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (0.14.0)
# Requirement already satisfied, skipping upgrade: requests~=2.20 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (2.21.0)
# Requirement already satisfied, skipping upgrade: colorclass~=2.2 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (2.2.0)
# Collecting python-socketio~=3.0 (from rasa_core)
#   Using cached https://files.pythonhosted.org/packages/b5/db/dc823aa0b3397e52ebe8bba62ee39d6b9a088377809bc230d3ad2e5d2448/python_socketio-3.1.2-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: fakeredis~=0.10.0 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (0.10.3)
# Collecting pydot~=1.4 (from rasa_core)
#   Using cached https://files.pythonhosted.org/packages/33/d1/b1479a770f66d962f545c2101630ce1d5592d90cb4f083d38862e93d16d2/pydot-1.4.1-py2.py3-none-any.whl
# Collecting pika~=0.12.0 (from rasa_core)
#   Using cached https://files.pythonhosted.org/packages/bf/48/72de47f63ba353bacd74b76bb65bc63620b0706d8b0471798087cd5a4916/pika-0.12.0-py2.py3-none-any.whl
# Collecting twilio~=6.0 (from rasa_core)
#   Using cached https://files.pythonhosted.org/packages/20/27/37c037cd547d673db2e2f26491eb21daf31be8529ffeb7bdc395d83bdd14/twilio-6.31.0-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: networkx~=2.2 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (2.2)
# Requirement already satisfied, skipping upgrade: packaging~=18.0 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (18.0)
# Requirement already satisfied, skipping upgrade: flask-cors~=3.0 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (3.0.7)
# Collecting webexteamssdk~=1.0 (from rasa_core)
# Requirement already satisfied, skipping upgrade: python-dateutil~=2.7 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (2.7.5)
# Collecting tensorflow~=1.13.0 (from rasa_core)
#   Using cached https://files.pythonhosted.org/packages/bc/70/45d3b9fab768215a2055c7819d39547a4b0b7401b4583094068741aff99b/tensorflow-1.13.2-cp37-cp37m-manylinux1_x86_64.whl
# Requirement already satisfied, skipping upgrade: tqdm~=4.0 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_core) (4.28.1)
# Collecting colorhash~=1.0 (from rasa_core)
#   Using cached https://files.pythonhosted.org/packages/0e/e1/50dbc513aa74e99eca4c47f2a8206711f0bec436fdddd95eebaf7eaaa1aa/colorhash-1.0.2-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: klein~=17.10 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_nlu[spacy]) (17.10.0)
# Requirement already satisfied, skipping upgrade: boto3~=1.9 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_nlu[spacy]) (1.9.238)
# Requirement already satisfied, skipping upgrade: simplejson~=3.13 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_nlu[spacy]) (3.16.0)
# Requirement already satisfied, skipping upgrade: cloudpickle~=0.6.1 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_nlu[spacy]) (0.6.1)
# Requirement already satisfied, skipping upgrade: future~=0.17.1 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_nlu[spacy]) (0.17.1)
# Requirement already satisfied, skipping upgrade: matplotlib~=2.2 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa_nlu[spacy]) (2.2.4)
# Collecting spacy<=2.0.18,>2.0; extra == "spacy" (from rasa_nlu[spacy])
#   Using cached https://files.pythonhosted.org/packages/cd/70/65504a011d7b262e73cfe470c36ca245a1f8e45b3b6661081289ffd72009/spacy-2.0.18-cp37-cp37m-manylinux1_x86_64.whl
# Collecting sklearn-crfsuite~=0.3.6; extra == "spacy" (from rasa_nlu[spacy])
#   Using cached https://files.pythonhosted.org/packages/25/74/5b7befa513482e6dee1f3dd68171a6c9dfc14c0eaa00f885ffeba54fe9b0/sklearn_crfsuite-0.3.6-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: greenlet>=0.4.14 in /home/bene/anaconda3/lib/python3.7/site-packages (from gevent~=1.3->rasa_core) (0.4.15)
# Collecting PyJWT (from flask-jwt-simple~=0.0.3->rasa_core)
#   Using cached https://files.pythonhosted.org/packages/87/8b/6a9f14b5f781697e51259d81657e6048fd31a113229cf346880bb7545565/PyJWT-1.7.1-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: prompt-toolkit~=2.0 in /home/bene/anaconda3/lib/python3.7/site-packages (from questionary>=1.0.1->rasa_core) (2.0.7)
# Requirement already satisfied, skipping upgrade: certifi in /home/bene/anaconda3/lib/python3.7/site-packages (from python-telegram-bot~=11.0->rasa_core) (2018.11.29)
# Requirement already satisfied, skipping upgrade: cryptography in /home/bene/anaconda3/lib/python3.7/site-packages (from python-telegram-bot~=11.0->rasa_core) (2.4.2)
# Requirement already satisfied, skipping upgrade: Werkzeug>=0.14 in /home/bene/anaconda3/lib/python3.7/site-packages (from flask~=1.0->rasa_core) (0.14.1)
# Requirement already satisfied, skipping upgrade: click>=5.1 in /home/bene/anaconda3/lib/python3.7/site-packages (from flask~=1.0->rasa_core) (7.0)
# Requirement already satisfied, skipping upgrade: itsdangerous>=0.24 in /home/bene/anaconda3/lib/python3.7/site-packages (from flask~=1.0->rasa_core) (1.1.0)
# Requirement already satisfied, skipping upgrade: Jinja2>=2.10 in /home/bene/anaconda3/lib/python3.7/site-packages (from flask~=1.0->rasa_core) (2.10)
# Requirement already satisfied, skipping upgrade: six>=1.4.0 in /home/bene/anaconda3/lib/python3.7/site-packages (from apscheduler~=3.0->rasa_core) (1.12.0)
# Requirement already satisfied, skipping upgrade: tzlocal>=1.2 in /home/bene/anaconda3/lib/python3.7/site-packages (from apscheduler~=3.0->rasa_core) (2.0.0)
# Requirement already satisfied, skipping upgrade: setuptools>=0.7 in /home/bene/anaconda3/lib/python3.7/site-packages (from apscheduler~=3.0->rasa_core) (40.6.3)
# Requirement already satisfied, skipping upgrade: websocket-client<0.55.0,>=0.35 in /home/bene/anaconda3/lib/python3.7/site-packages (from slackclient~=1.0->rasa_core) (0.54.0)
# Requirement already satisfied, skipping upgrade: PyYAML>=3.11 in /home/bene/anaconda3/lib/python3.7/site-packages (from pykwalify~=1.7.0->rasa_core) (3.13)
# Requirement already satisfied, skipping upgrade: docopt>=0.6.2 in /home/bene/anaconda3/lib/python3.7/site-packages (from pykwalify~=1.7.0->rasa_core) (0.6.2)
# Requirement already satisfied, skipping upgrade: humanfriendly>=4.7 in /home/bene/anaconda3/lib/python3.7/site-packages (from coloredlogs~=10.0->rasa_core) (4.18)
# Requirement already satisfied, skipping upgrade: ConfigArgParse~=0.13.0 in /home/bene/anaconda3/lib/python3.7/site-packages (from rasa-core-sdk~=0.14->rasa_core) (0.13.0)
# Requirement already satisfied, skipping upgrade: urllib3<1.25,>=1.21.1 in /home/bene/anaconda3/lib/python3.7/site-packages (from requests~=2.20->rasa_core) (1.24.1)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /home/bene/anaconda3/lib/python3.7/site-packages (from requests~=2.20->rasa_core) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /home/bene/anaconda3/lib/python3.7/site-packages (from requests~=2.20->rasa_core) (2.8)
# Collecting python-engineio>=3.2.0 (from python-socketio~=3.0->rasa_core)
#   Using cached https://files.pythonhosted.org/packages/2b/20/8e3ba16102ae2e245d70d9cb9fa48b076253fdb036dc43eea142294c2897/python_engineio-3.9.3-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: pyparsing>=2.1.4 in /home/bene/anaconda3/lib/python3.7/site-packages (from pydot~=1.4->rasa_core) (2.3.0)
# Requirement already satisfied, skipping upgrade: pysocks; python_version >= "3.0" in /home/bene/anaconda3/lib/python3.7/site-packages (from twilio~=6.0->rasa_core) (1.6.8)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /home/bene/anaconda3/lib/python3.7/site-packages (from networkx~=2.2->rasa_core) (4.3.0)
# Collecting requests-toolbelt (from webexteamssdk~=1.0->rasa_core)
#   Using cached https://files.pythonhosted.org/packages/60/ef/7681134338fc097acef8d9b2f8abe0458e4d87559c689a8c306d0957ece5/requests_toolbelt-0.9.1-py2.py3-none-any.whl
# Collecting tensorboard<1.14.0,>=1.13.0 (from tensorflow~=1.13.0->rasa_core)
#   Using cached https://files.pythonhosted.org/packages/0f/39/bdd75b08a6fba41f098b6cb091b9e8c7a80e1b4d679a581a0ccd17b10373/tensorboard-1.13.1-py3-none-any.whl
# Collecting keras-preprocessing>=1.0.5 (from tensorflow~=1.13.0->rasa_core)
#   Using cached https://files.pythonhosted.org/packages/28/6a/8c1f62c37212d9fc441a7e26736df51ce6f0e38455816445471f10da4f0a/Keras_Preprocessing-1.1.0-py2.py3-none-any.whl
# Collecting termcolor>=1.1.0 (from tensorflow~=1.13.0->rasa_core)
# Collecting keras-applications>=1.0.6 (from tensorflow~=1.13.0->rasa_core)
#   Using cached https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl
# Collecting protobuf>=3.6.1 (from tensorflow~=1.13.0->rasa_core)
#   Using cached https://files.pythonhosted.org/packages/4f/32/ba67677963d9cf557155d5a8f14ae0ffaf278a69a25fb03b5bc9e9e6fd52/protobuf-3.9.2-cp37-cp37m-manylinux1_x86_64.whl
# Collecting grpcio>=1.8.6 (from tensorflow~=1.13.0->rasa_core)
#   Using cached https://files.pythonhosted.org/packages/9e/ef/afc61af08d3c5e58a1ebcc3bb15b9537c515805ebbf0fe80e8ba9f9db38d/grpcio-1.24.0-cp37-cp37m-manylinux1_x86_64.whl
# Collecting astor>=0.6.0 (from tensorflow~=1.13.0->rasa_core)
#   Using cached https://files.pythonhosted.org/packages/d1/4f/950dfae467b384fc96bc6469de25d832534f6b4441033c39f914efd13418/astor-0.8.0-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: wheel>=0.26 in /home/bene/anaconda3/lib/python3.7/site-packages (from tensorflow~=1.13.0->rasa_core) (0.32.3)
# Collecting absl-py>=0.1.6 (from tensorflow~=1.13.0->rasa_core)
# Collecting tensorflow-estimator<1.14.0rc0,>=1.13.0 (from tensorflow~=1.13.0->rasa_core)
#   Using cached https://files.pythonhosted.org/packages/bb/48/13f49fc3fa0fdf916aa1419013bb8f2ad09674c275b4046d5ee669a46873/tensorflow_estimator-1.13.0-py2.py3-none-any.whl
# Collecting gast>=0.2.0 (from tensorflow~=1.13.0->rasa_core)
# Requirement already satisfied, skipping upgrade: incremental in /home/bene/anaconda3/lib/python3.7/site-packages (from klein~=17.10->rasa_nlu[spacy]) (17.5.0)
# Requirement already satisfied, skipping upgrade: Twisted>=15.5 in /home/bene/anaconda3/lib/python3.7/site-packages (from klein~=17.10->rasa_nlu[spacy]) (19.7.0)
# Requirement already satisfied, skipping upgrade: s3transfer<0.3.0,>=0.2.0 in /home/bene/anaconda3/lib/python3.7/site-packages (from boto3~=1.9->rasa_nlu[spacy]) (0.2.1)
# Requirement already satisfied, skipping upgrade: jmespath<1.0.0,>=0.7.1 in /home/bene/anaconda3/lib/python3.7/site-packages (from boto3~=1.9->rasa_nlu[spacy]) (0.9.4)
# Requirement already satisfied, skipping upgrade: botocore<1.13.0,>=1.12.238 in /home/bene/anaconda3/lib/python3.7/site-packages (from boto3~=1.9->rasa_nlu[spacy]) (1.12.238)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /home/bene/anaconda3/lib/python3.7/site-packages (from matplotlib~=2.2->rasa_nlu[spacy]) (1.0.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /home/bene/anaconda3/lib/python3.7/site-packages (from matplotlib~=2.2->rasa_nlu[spacy]) (0.10.0)
# Collecting thinc<6.13.0,>=6.12.1 (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy])
#   Using cached https://files.pythonhosted.org/packages/da/c0/f19586e8f0d9575a0df162f83bacfe131ced8ed8964434260c55275edce3/thinc-6.12.1-cp37-cp37m-manylinux1_x86_64.whl
# Collecting plac<1.0.0,>=0.9.6 (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy])
#   Using cached https://files.pythonhosted.org/packages/9e/9b/62c60d2f5bc135d2aa1d8c8a86aaf84edb719a59c7f11a4316259e61a298/plac-0.9.6-py2.py3-none-any.whl
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy])
#   Using cached https://files.pythonhosted.org/packages/73/fc/10eeacb926ec1e88cd62f79d9ac106b0a3e3fe5ff1690422d88c29bd0909/murmurhash-1.0.2-cp37-cp37m-manylinux1_x86_64.whl
# Collecting ujson>=1.35 (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy])
#   Using cached https://files.pythonhosted.org/packages/16/c4/79f3409bc710559015464e5f49b9879430d8f87498ecdc335899732e5377/ujson-1.35.tar.gz
# Requirement already satisfied, skipping upgrade: preshed<2.1.0,>=2.0.1 in /home/bene/anaconda3/lib/python3.7/site-packages (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (2.0.1)
# Requirement already satisfied, skipping upgrade: cymem<2.1.0,>=2.0.2 in /home/bene/anaconda3/lib/python3.7/site-packages (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (2.0.2)
# Collecting regex==2018.01.10 (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy])
#   Using cached https://files.pythonhosted.org/packages/76/f4/7146c3812f96fcaaf2d06ff6862582302626a59011ccb6f2833bb38d80f7/regex-2018.01.10.tar.gz
# Collecting dill<0.3,>=0.2 (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy])
# Collecting tabulate (from sklearn-crfsuite~=0.3.6; extra == "spacy"->rasa_nlu[spacy])
# Collecting python-crfsuite>=0.8.3 (from sklearn-crfsuite~=0.3.6; extra == "spacy"->rasa_nlu[spacy])
#   Using cached https://files.pythonhosted.org/packages/da/05/5cd3eb8dbbe3c787e3cf84d5767d95198298f7951bf8e40c46ebd8c80a32/python_crfsuite-0.9.6-cp37-cp37m-manylinux1_x86_64.whl
# Requirement already satisfied, skipping upgrade: wcwidth in /home/bene/anaconda3/lib/python3.7/site-packages (from prompt-toolkit~=2.0->questionary>=1.0.1->rasa_core) (0.1.7)
# Requirement already satisfied, skipping upgrade: cffi!=1.11.3,>=1.7 in /home/bene/anaconda3/lib/python3.7/site-packages (from cryptography->python-telegram-bot~=11.0->rasa_core) (1.11.5)
# Requirement already satisfied, skipping upgrade: asn1crypto>=0.21.0 in /home/bene/anaconda3/lib/python3.7/site-packages (from cryptography->python-telegram-bot~=11.0->rasa_core) (0.24.0)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in /home/bene/anaconda3/lib/python3.7/site-packages (from Jinja2>=2.10->flask~=1.0->rasa_core) (1.1.0)
# Collecting markdown>=2.6.8 (from tensorboard<1.14.0,>=1.13.0->tensorflow~=1.13.0->rasa_core)
#   Using cached https://files.pythonhosted.org/packages/c0/4e/fd492e91abdc2d2fcb70ef453064d980688762079397f779758e055f6575/Markdown-3.1.1-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: h5py in /home/bene/anaconda3/lib/python3.7/site-packages (from keras-applications>=1.0.6->tensorflow~=1.13.0->rasa_core) (2.8.0)
# Collecting mock>=2.0.0 (from tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow~=1.13.0->rasa_core)
#   Using cached https://files.pythonhosted.org/packages/05/d2/f94e68be6b17f46d2c353564da56e6fb89ef09faeeff3313a046cb810ca9/mock-3.0.5-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: attrs>=17.4.0 in /home/bene/anaconda3/lib/python3.7/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (18.2.0)
# Requirement already satisfied, skipping upgrade: hyperlink>=17.1.1 in /home/bene/anaconda3/lib/python3.7/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (19.0.0)
# Requirement already satisfied, skipping upgrade: PyHamcrest>=1.9.0 in /home/bene/anaconda3/lib/python3.7/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (1.9.0)
# Requirement already satisfied, skipping upgrade: constantly>=15.1 in /home/bene/anaconda3/lib/python3.7/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (15.1.0)
# Requirement already satisfied, skipping upgrade: zope.interface>=4.4.2 in /home/bene/anaconda3/lib/python3.7/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (4.6.0)
# Requirement already satisfied, skipping upgrade: Automat>=0.3.0 in /home/bene/anaconda3/lib/python3.7/site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (0.7.0)
# Requirement already satisfied, skipping upgrade: docutils<0.16,>=0.10 in /home/bene/anaconda3/lib/python3.7/site-packages (from botocore<1.13.0,>=1.12.238->boto3~=1.9->rasa_nlu[spacy]) (0.14)
# Collecting msgpack-numpy<0.4.4 (from thinc<6.13.0,>=6.12.1->spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy])
#   Using cached https://files.pythonhosted.org/packages/ad/45/464be6da85b5ca893cfcbd5de3b31a6710f636ccb8521b17bd4110a08d94/msgpack_numpy-0.4.3.2-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: cytoolz<0.10,>=0.9.0 in /home/bene/anaconda3/lib/python3.7/site-packages (from thinc<6.13.0,>=6.12.1->spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (0.9.0.1)
# Requirement already satisfied, skipping upgrade: wrapt<1.11.0,>=1.10.0 in /home/bene/anaconda3/lib/python3.7/site-packages (from thinc<6.13.0,>=6.12.1->spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (1.10.11)
# Requirement already satisfied, skipping upgrade: msgpack<0.6.0,>=0.5.6 in /home/bene/anaconda3/lib/python3.7/site-packages (from thinc<6.13.0,>=6.12.1->spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (0.5.6)
# Requirement already satisfied, skipping upgrade: pycparser in /home/bene/anaconda3/lib/python3.7/site-packages (from cffi!=1.11.3,>=1.7->cryptography->python-telegram-bot~=11.0->rasa_core) (2.19)
# Requirement already satisfied, skipping upgrade: toolz>=0.8.0 in /home/bene/anaconda3/lib/python3.7/site-packages (from cytoolz<0.10,>=0.9.0->thinc<6.13.0,>=6.12.1->spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (0.9.0)
# Building wheels for collected packages: ujson, regex
#   Running setup.py bdist_wheel for ujson ... error
#   Complete output from command /home/bene/anaconda3/bin/python -u -c "import setuptools, tokenize;__file__='/tmp/pip-install-7k_nt9ez/ujson/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /tmp/pip-wheel-sw0tf9js --python-tag cp37:
#   Warning: 'classifiers' should be a list, got type 'filter'
#   running bdist_wheel
#   running build
#   running build_ext
#   building 'ujson' extension
#   creating build
#   creating build/temp.linux-x86_64-3.7
#   creating build/temp.linux-x86_64-3.7/python
#   creating build/temp.linux-x86_64-3.7/lib
#   gcc -pthread -B /home/bene/anaconda3/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I./python -I./lib -I/home/bene/anaconda3/include/python3.7m -c ./python/ujson.c -o build/temp.linux-x86_64-3.7/./python/ujson.o -D_GNU_SOURCE
#   unable to execute 'gcc': No such file or directory
#   error: command 'gcc' failed with exit status 1
#
#   ----------------------------------------
#   Failed building wheel for ujson
#   Running setup.py clean for ujson
#   Running setup.py bdist_wheel for regex ... error
#   Complete output from command /home/bene/anaconda3/bin/python -u -c "import setuptools, tokenize;__file__='/tmp/pip-install-7k_nt9ez/regex/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /tmp/pip-wheel-n6jt39fp --python-tag cp37:
#   /home/bene/anaconda3/lib/python3.7/site-packages/setuptools/dist.py:470: UserWarning: Normalizing '2018.01.10' to '2018.1.10'
#     normalized_version,
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-3.7
#   copying regex_3/regex.py -> build/lib.linux-x86_64-3.7
#   copying regex_3/_regex_core.py -> build/lib.linux-x86_64-3.7
#   copying regex_3/test_regex.py -> build/lib.linux-x86_64-3.7
#   running build_ext
#   building '_regex' extension
#   creating build/temp.linux-x86_64-3.7
#   creating build/temp.linux-x86_64-3.7/regex_3
#   gcc -pthread -B /home/bene/anaconda3/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/home/bene/anaconda3/include/python3.7m -c regex_3/_regex.c -o build/temp.linux-x86_64-3.7/regex_3/_regex.o
#   unable to execute 'gcc': No such file or directory
#   error: command 'gcc' failed with exit status 1
#
#   ----------------------------------------
#   Failed building wheel for regex
#   Running setup.py clean for regex
# Failed to build ujson regex
# Installing collected packages: PyJWT, flask-jwt-simple, python-telegram-bot, scikit-learn, msgpack-numpy, dill, plac, murmurhash, thinc, ujson, regex, spacy, tabulate, python-crfsuite, sklearn-crfsuite, rasa-nlu, python-engineio, python-socketio, pydot, pika, twilio, requests-toolbelt, webexteamssdk, markdown, absl-py, grpcio, protobuf, tensorboard, keras-preprocessing, termcolor, keras-applications, astor, mock, tensorflow-estimator, gast, tensorflow, colorhash, rasa-core
#   Running setup.py install for ujson ... error
#     Complete output from command /home/bene/anaconda3/bin/python -u -c "import setuptools, tokenize;__file__='/tmp/pip-install-7k_nt9ez/ujson/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record /tmp/pip-record-1dxibmf4/install-record.txt --single-version-externally-managed --compile:
#     Warning: 'classifiers' should be a list, got type 'filter'
#     running install
#     running build
#     running build_ext
#     building 'ujson' extension
#     creating build
#     creating build/temp.linux-x86_64-3.7
#     creating build/temp.linux-x86_64-3.7/python
#     creating build/temp.linux-x86_64-3.7/lib
#     gcc -pthread -B /home/bene/anaconda3/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I./python -I./lib -I/home/bene/anaconda3/include/python3.7m -c ./python/ujson.c -o build/temp.linux-x86_64-3.7/./python/ujson.o -D_GNU_SOURCE
#     unable to execute 'gcc': No such file or directory
#     error: command 'gcc' failed with exit status 1
#
#     ----------------------------------------
# Command "/home/bene/anaconda3/bin/python -u -c "import setuptools, tokenize;__file__='/tmp/pip-install-7k_nt9ez/ujson/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record /tmp/pip-record-1dxibmf4/install-record.txt --single-version-externally-managed --compile" failed with error code 1 in /tmp/pip-install-7k_nt9ez/ujson/
# /home/bene/anaconda3/bin/python: No module named spacy
# /home/bene/anaconda3/bin/python: No module named spacy

# %%
import rasa_nlu
import rasa_core
import spacy

print("rasa_nlu: {} rasa_core: {}".format(rasa_nlu.__version__, rasa_core.__version__))
print("Loading spaCy language model...")
print(spacy.load("en")("Hello world!"))
# Out:
# rasa_nlu: 0.15.1 rasa_core: 0.14.5
# Loading spaCy language model...
# Hello world!

# %% [markdown]
# ## Lets start with the intents

# %%
nlu_md = """

## intent:greet
- hey
- hello there
- hi
- hello there
- good morning
- good evening
- moin
- hey there
- let's go
- hey dude
- goodmorning
- goodevening
- good afternoon

## intent:goodbye
- cu
- good by
- cee you later
- good night
- good afternoon
- bye
- goodbye
- have a nice day
- see you around
- bye bye
- see you later

## intent:mood_affirm
- yes
- indeed
- of course
- that sounds good
- correct

## intent:mood_deny
- no
- never
- I don't think so
- don't like that
- no way
- not really

## intent:mood_great
- perfect
- very good
- great
- amazing
- feeling like a king
- wonderful
- I am feeling very good
- I am great
- I am amazing
- I am going to save the world
- super
- extremely good
- so so perfect
- so good
- so perfect

## intent:mood_unhappy
- my day was horrible
- I am sad
- I don't feel very well
- I am disappointed
- super sad
- I'm so sad
- sad
- very sad
- unhappy
- bad
- very bad
- awful
- terrible
- not so good
- not very good
- extremly sad
- so saad
- Quite bad - can I get a cute picture of a [bird](group:birds), please?
- Really bad and only [doggo](group:shibes) pics and change that.
- Not good. The only thing that could make me fell better is a picture of a cute [kitten](group:cats).
- so sad. Only the picture of a [puppy](group:shibes) could make it better.
- I am very sad. I need a [cat](group:cats) picture.
- Extremely sad. Only the cute [doggo](group:shibes) pics can make me feel better.
- Bad. Please show me a [bird](group:birds) pic!
- Pretty bad to be honest. Can you show me a [puppy](group:shibes) picture to make me fell better?

## intent: inform
- A [dog](group:shibes)
- [dog](group:shibes)
- [bird](group:birds)
- a [cat](group:cats)
- [cat](group:cats)
- a [bird](group:birds)
- of a [dog](group:shibes)
- of a [cat](group:cats)
- a [bird](group:birds), please
- a [dog](group:shibes), please
"""

# %store nlu_md > nlu.md
# Out:
# Writing 'nlu_md' (str) to file 'nlu.md'.

# %%
config = """
language: "en"

pipeline:
- name: "nlp_spacy"                   # loads the spacy language model
- name: "tokenizer_spacy"             # splits the sentence into tokens
- name: "intent_featurizer_spacy"     # transform the sentence into a vector representation
- name: "intent_classifier_sklearn"   # uses the vector representation to classify using SVM
- name: "ner_crf"
- name: "ner_synonyms"
""" 

# %store config > config.yml
# Out:
# Writing 'config' (str) to file 'config.yml'.

# %% [markdown]
# ## Training the NLU Model

# %%
from rasa_nlu.training_data import load_data
from rasa_nlu.config import RasaNLUModelConfig
from rasa_nlu.model import Trainer
from rasa_nlu import config

# loading the nlu training samples
training_data = load_data("nlu.md")

# trainer to educate our pipeline
trainer = Trainer(config.load("config.yml"))

# train the model!
interpreter = trainer.train(training_data)

# store it for future use
model_directory = trainer.persist("./models/nlu", fixed_model_name="current")
# Out:
# INFO:rasa_nlu.training_data.loading:Training data format of nlu.md is md
# INFO:rasa_nlu.training_data.training_data:Training data stats:
# 	- intent examples: 85 (7 distinct intents)
# 	- Found intents: 'mood_unhappy', 'mood_great', 'greet', 'mood_deny', 'inform', 'mood_affirm', 'goodbye'
# 	- entity examples: 18 (1 distinct entities)
# 	- found entities: 'group'
#
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `nlp_spacy`, you should change it to its class name: `SpacyNLP`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `tokenizer_spacy`, you should change it to its class name: `SpacyTokenizer`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `intent_featurizer_spacy`, you should change it to its class name: `SpacyFeaturizer`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `intent_classifier_sklearn`, you should change it to its class name: `SklearnIntentClassifier`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `ner_crf`, you should change it to its class name: `CRFEntityExtractor`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `ner_synonyms`, you should change it to its class name: `EntitySynonymMapper`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `nlp_spacy`, you should change it to its class name: `SpacyNLP`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `nlp_spacy`, you should change it to its class name: `SpacyNLP`.
# INFO:rasa_nlu.utils.spacy_utils:Trying to load spacy model with name 'en'
# INFO:rasa_nlu.components:Added 'SpacyNLP' to component cache. Key 'SpacyNLP-en'.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `tokenizer_spacy`, you should change it to its class name: `SpacyTokenizer`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `tokenizer_spacy`, you should change it to its class name: `SpacyTokenizer`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `intent_featurizer_spacy`, you should change it to its class name: `SpacyFeaturizer`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `intent_featurizer_spacy`, you should change it to its class name: `SpacyFeaturizer`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `intent_classifier_sklearn`, you should change it to its class name: `SklearnIntentClassifier`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `intent_classifier_sklearn`, you should change it to its class name: `SklearnIntentClassifier`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `ner_crf`, you should change it to its class name: `CRFEntityExtractor`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `ner_crf`, you should change it to its class name: `CRFEntityExtractor`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `ner_synonyms`, you should change it to its class name: `EntitySynonymMapper`.
# WARNING:rasa_nlu.registry:DEPRECATION warning: your nlu config file contains old style component name `ner_synonyms`, you should change it to its class name: `EntitySynonymMapper`.
# INFO:rasa_nlu.model:Starting to train component SpacyNLP
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component SpacyTokenizer
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component SpacyFeaturizer
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component SklearnIntentClassifier
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    0.1s finished
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component CRFEntityExtractor
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component EntitySynonymMapper
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Successfully saved model into '/home/bene/Documents/jupyter/bot-rasa-test/models/nlu/default/current'
# Fitting 2 folds for each of 6 candidates, totalling 12 fits

# %% [markdown]
# ## Using the model

# %%
pprint(interpreter.parse("Show me a picture of a dog"))
# Out:
# {
#   "intent": {
#     "name": "mood_unhappy",
#     "confidence": 0.4616500168830293
#   },
#   "entities": [
#     {
#       "start": 23,
#       "end": 26,
#       "value": "shibes",
#       "entity": "group",
#       "confidence": 0.9755708191800945,
#       "extractor": "CRFEntityExtractor",
#       "processors": [
#         "EntitySynonymMapper"
#       ]
#     }
#   ],
#   "intent_ranking": [
#     {
#       "name": "mood_unhappy",
#       "confidence": 0.4616500168830293
#     },
#     {
#       "name": "inform",
#       "confidence": 0.18959543916093147
#     },
#     {
#       "name": "goodbye",
#       "confidence": 0.12492460246592856
#     },
#     {
#       "name": "mood_great",
#       "confidence": 0.07681435755616046
#     },
#     {
#       "name": "mood_affirm",
#       "confidence": 0.06403989530826093
#     },
#     {
#       "name": "greet",
#       "confidence": 0.05932626092645232
#     },
#     {
#       "name": "mood_deny",
#       "confidence": 0.02364942769923733
#     }
#   ],
#   "text": "Show me a picture of a dog"
# }

# %%
from rasa_nlu.evaluate import run_evaluation

run_evaluation("nlu.md", model_directory)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-22-4a2e157bcd0b> in <module>
# ----> 1 from rasa_nlu.evaluate import run_evaluation
#       2
#       3 run_evaluation("nlu.md", model_directory)
#
# ImportError: cannot import name 'run_evaluation' from 'rasa_nlu.evaluate' (/home/bene/anaconda3/lib/python3.7/site-packages/rasa_nlu/evaluate.py)

# %% [markdown]
# # Conversation

# %%
stories_md = """
## happy path               <!-- name of the story - just for debugging -->
* greet              
  - utter_greet
* mood_great               <!-- user utterance, in format intent[entities] -->
  - utter_happy
* mood_affirm
  - utter_happy
* mood_affirm
  - utter_goodbye
  
## sad path 1               <!-- this is already the start of the next story -->
* greet
  - utter_greet             <!-- action the bot should execute -->
* mood_unhappy
  - utter_ask_picture
* inform{"animal":"dog"}  
  - action_retrieve_image
  - utter_did_that_help
* mood_affirm
  - utter_happy

## sad path 2
* greet
  - utter_greet
* mood_unhappy
  - utter_ask_picture
* inform{"group":"cat"}
  - action_retrieve_image
  - utter_did_that_help
* mood_deny
  - utter_goodbye
  
## sad path 3
* greet
  - utter_greet
* mood_unhappy{"group":"puppy"}
  - action_retrieve_image
  - utter_did_that_help
* mood_affirm
  - utter_happy
  
## strange user
* mood_affirm
  - utter_happy
* mood_affirm
  - utter_unclear

## say goodbye
* goodbye
  - utter_goodbye

## fallback
- utter_unclear

"""

# %store stories_md > stories.md
# Out:
# Writing 'stories_md' (str) to file 'stories.md'.

# %% [markdown]
# ## Domain

# %%
domain_yml = """
intents:
- greet
- goodbye
- mood_affirm
- mood_deny
- mood_great
- mood_unhappy
- inform

slots:
  group:
    type: text
    
entities:
- group

actions:
- utter_greet
- utter_did_that_help
- utter_happy
- utter_goodbye
- utter_unclear
- utter_ask_picture
- action_retrieve_image

templates:
  utter_greet:
  - text: "Hey! How are you?"

  utter_did_that_help:
  - text: "Did that help you?"

  utter_unclear:
  - text: "I am not sure what you are aiming for."
  
  utter_happy:
  - text: "Great carry on!"

  utter_goodbye:
  - text: "Bye"
  
  utter_ask_picture:
  - text: "To cheer you up, I can show you a cute picture of a dog, cat or a bird. Which one do you choose?"
  
  action_retrieve_image:
  - text: "sorry this is just a workaroud, feel better?"
  
"""

# %store domain_yml > domain.yml
# Out:
# Writing 'domain_yml' (str) to file 'domain.yml'.

# %%
from rasa_core.actions import Action
from rasa_core.events import SlotSet
from IPython.core.display import Image, display

import requests

class ApiAction(Action):
    def name(self):
        return "action_retrieve_image"

    def run(self, dispatcher, tracker, domain):
        
        group = tracker.get_slot('group')
        
        r = requests.get('http://shibe.online/api/{}?count=1&urls=true&httpsUrls=true'.format(group))
        response = r.content.decode()
        response = response.replace('["',"")
        response = response.replace('"]',"")
   
        
        #display(Image(response[0], height=550, width=520))
        dispatcher.utter_message("Here is something to cheer you up: {}".format(response))

# %%
from IPython.display import Image
from rasa_core.agent import Agent

agent = Agent('domain.yml')
agent.visualize("stories.md", "story_graph.png", max_history=2)
Image(filename="story_graph.png")
# Out:
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=1]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=1]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=1]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=1]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=1]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=1]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=1]
# Processed Story Blocks: 100%|██████████| 7/7 [00:00<00:00, 500.19it/s, # trackers=1]

# %%
from rasa_core.policies import FallbackPolicy, KerasPolicy, MemoizationPolicy
from rasa_core.agent import Agent

# this will catch predictions the model isn't very certain about
# there is a threshold for the NLU predictions as well as the action predictions


agent = Agent('domain.yml', policies=[MemoizationPolicy(), KerasPolicy()])

# loading our neatly defined training dialogues
training_data = agent.load_data('stories.md')

agent.train(
    training_data
)

agent.persist('models/dialogue')
# Out:
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=1]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=1]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=1]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=1]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=1]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=1]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=1]
# Processed Story Blocks: 100%|██████████| 7/7 [00:00<00:00, 530.74it/s, # trackers=1]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=7]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=7]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=7]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=7]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=7]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=7]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=7]
# Processed Story Blocks: 100%|██████████| 7/7 [00:00<00:00, 351.66it/s, # trackers=7]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=11]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=11]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=11]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=11]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=11]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=11]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=11]
# Processed Story Blocks: 100%|██████████| 7/7 [00:00<00:00, 165.36it/s, # trackers=11]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=12]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=12]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=12]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=12]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=12]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=12]
# Processed Story Blocks:   0%|          | 0/7 [00:00<?, ?it/s, # trackers=12]
# Processed Story Blocks: 100%|██████████| 7/7 [00:00<00:00, 172.89it/s, # trackers=12]
# Processed actions: 0it [00:00, ?it/s]
# Processed actions: 0it [00:00, ?it/s, # examples=1]
# Processed actions: 0it [00:00, ?it/s, # examples=2]
# Processed actions: 0it [00:00, ?it/s, # examples=3]
# Processed actions: 0it [00:00, ?it/s, # examples=4]
# Processed actions: 0it [00:00, ?it/s, # examples=5]
# Processed actions: 0it [00:00, ?it/s, # examples=6]
# Processed actions: 0it [00:00, ?it/s, # examples=7]
# Processed actions: 0it [00:00, ?it/s, # examples=8]
# Processed actions: 0it [00:00, ?it/s, # examples=9]
# Processed actions: 0it [00:00, ?it/s, # examples=10]
# Processed actions: 0it [00:00, ?it/s, # examples=11]
# Processed actions: 0it [00:00, ?it/s, # examples=12]
# Processed actions: 0it [00:00, ?it/s, # examples=13]
# Processed actions: 0it [00:00, ?it/s, # examples=14]
# Processed actions: 0it [00:00, ?it/s, # examples=15]
# Processed actions: 0it [00:00, ?it/s, # examples=16]
# Processed actions: 0it [00:00, ?it/s, # examples=17]
# Processed actions: 0it [00:00, ?it/s, # examples=18]
# Processed actions: 0it [00:00, ?it/s, # examples=19]
# Processed actions: 0it [00:00, ?it/s, # examples=20]
# Processed actions: 0it [00:00, ?it/s, # examples=21]
# Processed actions: 0it [00:00, ?it/s, # examples=22]
# Processed actions: 0it [00:00, ?it/s, # examples=23]
# Processed actions: 0it [00:00, ?it/s, # examples=24]
# Processed actions: 0it [00:00, ?it/s, # examples=25]
# Processed actions: 0it [00:00, ?it/s, # examples=26]
# Processed actions: 0it [00:00, ?it/s, # examples=27]
# Processed actions: 0it [00:00, ?it/s, # examples=28]
# Processed actions: 0it [00:00, ?it/s, # examples=29]
# Processed actions: 0it [00:00, ?it/s, # examples=30]
# Processed actions: 0it [00:00, ?it/s, # examples=31]
# Processed actions: 0it [00:00, ?it/s, # examples=32]
# Processed actions: 0it [00:00, ?it/s, # examples=33]
# Processed actions: 33it [00:00, 437.33it/s, # examples=33]WARNING:tensorflow:From /home/bene/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/bene/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/backend.py:4010: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# INFO:rasa_core.policies.keras_policy:Fitting model with 240 total samples and a validation split of 0.1
# WARNING:tensorflow:From /home/bene/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# masking (Masking)            (None, 5, 24)             0
# _________________________________________________________________
# lstm (LSTM)                  (None, 32)                7296
# _________________________________________________________________
# dense (Dense)                (None, 15)                495
# _________________________________________________________________
# activation (Activation)      (None, 15)                0
# =================================================================
# Total params: 7,791
# Trainable params: 7,791
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 240/240 [==============================] - 1s 4ms/sample - loss: 2.6300 - acc: 0.2375
# Epoch 2/100
# 240/240 [==============================] - 0s 314us/sample - loss: 2.4944 - acc: 0.4750
# Epoch 3/100
# 240/240 [==============================] - 0s 403us/sample - loss: 2.3666 - acc: 0.4708
# Epoch 4/100
# 240/240 [==============================] - 0s 295us/sample - loss: 2.2092 - acc: 0.4708
# Epoch 5/100
# 240/240 [==============================] - 0s 241us/sample - loss: 2.0722 - acc: 0.4708
# Epoch 6/100
# 240/240 [==============================] - 0s 225us/sample - loss: 1.9740 - acc: 0.4708
# Epoch 7/100
# 240/240 [==============================] - 0s 237us/sample - loss: 1.9058 - acc: 0.4708
# Epoch 8/100
# 240/240 [==============================] - 0s 217us/sample - loss: 1.8269 - acc: 0.4708
# Epoch 9/100
# 240/240 [==============================] - 0s 249us/sample - loss: 1.7948 - acc: 0.4708
# Epoch 10/100
# 240/240 [==============================] - 0s 223us/sample - loss: 1.7545 - acc: 0.4708
# Epoch 11/100
# 240/240 [==============================] - 0s 261us/sample - loss: 1.7020 - acc: 0.4708
# Epoch 12/100
# 240/240 [==============================] - 0s 256us/sample - loss: 1.6873 - acc: 0.4708
# Epoch 13/100
# 240/240 [==============================] - 0s 292us/sample - loss: 1.6325 - acc: 0.4708
# Epoch 14/100
# 240/240 [==============================] - 0s 264us/sample - loss: 1.6118 - acc: 0.4708
# Epoch 15/100
# 240/240 [==============================] - 0s 304us/sample - loss: 1.5612 - acc: 0.4708
# Epoch 16/100
# 240/240 [==============================] - 0s 383us/sample - loss: 1.5337 - acc: 0.4708
# Epoch 17/100
# 240/240 [==============================] - 0s 312us/sample - loss: 1.5029 - acc: 0.4708
# Epoch 18/100
# 240/240 [==============================] - 0s 339us/sample - loss: 1.4874 - acc: 0.4708
# Epoch 19/100
# 240/240 [==============================] - 0s 333us/sample - loss: 1.4468 - acc: 0.4750
# Epoch 20/100
# 240/240 [==============================] - 0s 278us/sample - loss: 1.4076 - acc: 0.4875
# Epoch 21/100
# 240/240 [==============================] - 0s 327us/sample - loss: 1.3490 - acc: 0.5042
# Epoch 22/100
# 240/240 [==============================] - 0s 308us/sample - loss: 1.3329 - acc: 0.5000
# Epoch 23/100
# 240/240 [==============================] - 0s 329us/sample - loss: 1.3026 - acc: 0.4958
# Epoch 24/100
# 240/240 [==============================] - 0s 334us/sample - loss: 1.2466 - acc: 0.5250
# Epoch 25/100
# 240/240 [==============================] - 0s 331us/sample - loss: 1.2107 - acc: 0.5375
# Epoch 26/100
# 240/240 [==============================] - 0s 335us/sample - loss: 1.1644 - acc: 0.5375
# Epoch 27/100
# 240/240 [==============================] - 0s 354us/sample - loss: 1.1446 - acc: 0.5500
# Epoch 28/100
# 240/240 [==============================] - 0s 325us/sample - loss: 1.1119 - acc: 0.5833
# Epoch 29/100
# 240/240 [==============================] - 0s 311us/sample - loss: 1.0737 - acc: 0.6167
# Epoch 30/100
# 240/240 [==============================] - 0s 299us/sample - loss: 1.0530 - acc: 0.6375
# Epoch 31/100
# 240/240 [==============================] - 0s 318us/sample - loss: 1.0074 - acc: 0.6750
# Epoch 32/100
# 240/240 [==============================] - 0s 322us/sample - loss: 0.9863 - acc: 0.6667
# Epoch 33/100
# 240/240 [==============================] - 0s 387us/sample - loss: 0.9671 - acc: 0.7042
# Epoch 34/100
# 240/240 [==============================] - 0s 277us/sample - loss: 0.9206 - acc: 0.7083
# Epoch 35/100
# 240/240 [==============================] - 0s 258us/sample - loss: 0.8948 - acc: 0.7167
# Epoch 36/100
# 240/240 [==============================] - 0s 363us/sample - loss: 0.8612 - acc: 0.7375
# Epoch 37/100
# 240/240 [==============================] - 0s 345us/sample - loss: 0.8327 - acc: 0.8042
# Epoch 38/100
# 240/240 [==============================] - 0s 321us/sample - loss: 0.8294 - acc: 0.7792
# Epoch 39/100
# 240/240 [==============================] - 0s 317us/sample - loss: 0.7867 - acc: 0.7958
# Epoch 40/100
# 240/240 [==============================] - 0s 323us/sample - loss: 0.7655 - acc: 0.8042
# Epoch 41/100
# 240/240 [==============================] - 0s 327us/sample - loss: 0.7620 - acc: 0.7917
# Epoch 42/100
# 240/240 [==============================] - 0s 244us/sample - loss: 0.7556 - acc: 0.7667
# Epoch 43/100
# 240/240 [==============================] - 0s 215us/sample - loss: 0.7336 - acc: 0.8250
# Epoch 44/100
# 240/240 [==============================] - 0s 306us/sample - loss: 0.7377 - acc: 0.7875
# Epoch 45/100
# 240/240 [==============================] - 0s 356us/sample - loss: 0.6896 - acc: 0.8250
# Epoch 46/100
# 240/240 [==============================] - 0s 338us/sample - loss: 0.6759 - acc: 0.8125
# Epoch 47/100
# 240/240 [==============================] - 0s 244us/sample - loss: 0.6575 - acc: 0.8375
# Epoch 48/100
# 240/240 [==============================] - 0s 262us/sample - loss: 0.6146 - acc: 0.8458
# Epoch 49/100
# 240/240 [==============================] - 0s 259us/sample - loss: 0.6266 - acc: 0.8375
# Epoch 50/100
# 240/240 [==============================] - 0s 299us/sample - loss: 0.6134 - acc: 0.8542
# Epoch 51/100
# 240/240 [==============================] - 0s 341us/sample - loss: 0.6059 - acc: 0.8625
# Epoch 52/100
# 240/240 [==============================] - 0s 351us/sample - loss: 0.5793 - acc: 0.8500
# Epoch 53/100
# 240/240 [==============================] - 0s 253us/sample - loss: 0.5672 - acc: 0.8750
# Epoch 54/100
# 240/240 [==============================] - 0s 345us/sample - loss: 0.5371 - acc: 0.8542
# Epoch 55/100
# 240/240 [==============================] - 0s 310us/sample - loss: 0.5292 - acc: 0.8875
# Epoch 56/100
# 240/240 [==============================] - 0s 317us/sample - loss: 0.5393 - acc: 0.8708
# Epoch 57/100
# 240/240 [==============================] - 0s 306us/sample - loss: 0.5207 - acc: 0.8875
# Epoch 58/100
# 240/240 [==============================] - 0s 372us/sample - loss: 0.4937 - acc: 0.8833
# Epoch 59/100
# 240/240 [==============================] - 0s 313us/sample - loss: 0.4899 - acc: 0.8667
# Epoch 60/100
# 240/240 [==============================] - 0s 286us/sample - loss: 0.4873 - acc: 0.8625
# Epoch 61/100
# 240/240 [==============================] - 0s 340us/sample - loss: 0.4723 - acc: 0.8833
# Epoch 62/100
# 240/240 [==============================] - 0s 323us/sample - loss: 0.4630 - acc: 0.8792
# Epoch 63/100
# 240/240 [==============================] - 0s 339us/sample - loss: 0.4274 - acc: 0.9167
# Epoch 64/100
# 240/240 [==============================] - 0s 302us/sample - loss: 0.4293 - acc: 0.9125
# Epoch 65/100
# 240/240 [==============================] - 0s 310us/sample - loss: 0.4120 - acc: 0.9375
# Epoch 66/100
# 240/240 [==============================] - 0s 354us/sample - loss: 0.4156 - acc: 0.9000
# Epoch 67/100
# 240/240 [==============================] - 0s 331us/sample - loss: 0.3874 - acc: 0.9292
# Epoch 68/100
# 240/240 [==============================] - 0s 339us/sample - loss: 0.3734 - acc: 0.9208
# Epoch 69/100
# 240/240 [==============================] - 0s 303us/sample - loss: 0.3845 - acc: 0.9542
# Epoch 70/100
# 240/240 [==============================] - 0s 301us/sample - loss: 0.3878 - acc: 0.9208
# Epoch 71/100
# 240/240 [==============================] - 0s 314us/sample - loss: 0.3717 - acc: 0.9375
# Epoch 72/100
# 240/240 [==============================] - 0s 326us/sample - loss: 0.3531 - acc: 0.9250
# Epoch 73/100
# 240/240 [==============================] - 0s 262us/sample - loss: 0.3731 - acc: 0.9167
# Epoch 74/100
# 240/240 [==============================] - 0s 309us/sample - loss: 0.3527 - acc: 0.9250
# Epoch 75/100
# 240/240 [==============================] - 0s 336us/sample - loss: 0.3285 - acc: 0.9333
# Epoch 76/100
# 240/240 [==============================] - 0s 314us/sample - loss: 0.3073 - acc: 0.9542
# Epoch 77/100
# 240/240 [==============================] - 0s 334us/sample - loss: 0.3220 - acc: 0.9417
# Epoch 78/100
# 240/240 [==============================] - 0s 303us/sample - loss: 0.3156 - acc: 0.9458
# Epoch 79/100
# 240/240 [==============================] - 0s 261us/sample - loss: 0.3102 - acc: 0.9417
# Epoch 80/100
# 240/240 [==============================] - 0s 325us/sample - loss: 0.3137 - acc: 0.9333
# Epoch 81/100
# 240/240 [==============================] - 0s 327us/sample - loss: 0.2779 - acc: 0.9792
# Epoch 82/100
# 240/240 [==============================] - 0s 304us/sample - loss: 0.2671 - acc: 0.9667
# Epoch 83/100
# 240/240 [==============================] - 0s 322us/sample - loss: 0.2937 - acc: 0.9375
# Epoch 84/100
# 240/240 [==============================] - 0s 336us/sample - loss: 0.2647 - acc: 0.9458
# Epoch 85/100
# 240/240 [==============================] - 0s 342us/sample - loss: 0.3092 - acc: 0.9333
# Epoch 86/100
# 240/240 [==============================] - 0s 314us/sample - loss: 0.3006 - acc: 0.9417
# Epoch 87/100
# 240/240 [==============================] - 0s 284us/sample - loss: 0.2786 - acc: 0.9375
# Epoch 88/100
# 240/240 [==============================] - 0s 287us/sample - loss: 0.2557 - acc: 0.9583
# Epoch 89/100
# 240/240 [==============================] - 0s 293us/sample - loss: 0.2658 - acc: 0.9583
# Epoch 90/100
# 240/240 [==============================] - 0s 277us/sample - loss: 0.2364 - acc: 0.9500
# Epoch 91/100
# 240/240 [==============================] - 0s 301us/sample - loss: 0.2293 - acc: 0.9583
# Epoch 92/100
# 240/240 [==============================] - 0s 283us/sample - loss: 0.2403 - acc: 0.9583
# Epoch 93/100
# 240/240 [==============================] - 0s 329us/sample - loss: 0.2521 - acc: 0.9625
# Epoch 94/100
# 240/240 [==============================] - 0s 365us/sample - loss: 0.2424 - acc: 0.9542
# Epoch 95/100
# 240/240 [==============================] - 0s 324us/sample - loss: 0.2193 - acc: 0.9625
# Epoch 96/100
# 240/240 [==============================] - 0s 342us/sample - loss: 0.2245 - acc: 0.9542
# Epoch 97/100
# 240/240 [==============================] - 0s 323us/sample - loss: 0.2146 - acc: 0.9583
# Epoch 98/100
# 240/240 [==============================] - 0s 262us/sample - loss: 0.1932 - acc: 0.9667
# Epoch 99/100
# 240/240 [==============================] - 0s 318us/sample - loss: 0.2161 - acc: 0.9625
# Epoch 100/100
# 240/240 [==============================] - 0s 336us/sample - loss: 0.1798 - acc: 0.9750
# INFO:rasa_core.policies.keras_policy:Done fitting keras policy model
# INFO:rasa_core.agent:Persisted model to '/home/bene/Documents/jupyter/bot-rasa-test/models/dialogue'

# %%
from rasa_core.agent import Agent
agent = Agent.load('models/dialogue', interpreter=model_directory)
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
# INFO:rasa_nlu.components:Added 'SpacyNLP' to component cache. Key 'SpacyNLP-en'.

# %%
print("Your bot is ready to talk! Type your messages here or send 'stop'")
while True:
    a = input()
    if a == 'stop':
        break
    responses = agent.handle_message(a)
    for response in responses:
        print(response["text"])
# Out:
# Your bot is ready to talk! Type your messages here or send 'stop'
# Hello
# WARNING:rasa_core.agent:Passing a text to `agent.handle_message(...)` is deprecated. Rather use `agent.handle_text(...)`.
# Hey! How are you?
# I am very sad
# WARNING:rasa_core.agent:Passing a text to `agent.handle_message(...)` is deprecated. Rather use `agent.handle_text(...)`.
# To cheer you up, I can show you a cute picture of a dog, cat or a bird. Which one do you choose?
# A puppy
# WARNING:rasa_core.agent:Passing a text to `agent.handle_message(...)` is deprecated. Rather use `agent.handle_text(...)`.
# ERROR:rasa_core.processor:Encountered an exception while running action 'action_retrieve_image'. Bot will continue, but the actions events are lost. Make sure to fix the exception in your custom code.
# Did that help you?
# no
# WARNING:rasa_core.agent:Passing a text to `agent.handle_message(...)` is deprecated. Rather use `agent.handle_text(...)`.
# Bye
# stop
